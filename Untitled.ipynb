# %%
import os
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()

# %%
files = []
for filename in os.listdir('swcm_logs'):
    if filename.startswith('access'):
        files.append(filename)

# %%
matches = ["Zabbix", "docs", "health", "debug", "metrics", "stats", "openapi", "v1", "v3", "favicon"]

rows = []
for filename in files:
    print(f"Opening file {filename}")
    with open(f"swcm_logs/{filename}", 'r') as logfile:
        for line in logfile:
            if any(x in line for x in matches):
                continue
            try:
                line = line.split()
                date = datetime.strptime(line[3][1:], '%d/%b/%Y:%H:%M:%S')
                tz = line[4][:-1]
                ip = line[0]
                method = line[5][1:]
                url = line[6]
                statusCode = line[8]
                responseTime = line[14][5:-1]
                rows.append((date, str(ip), str(method), str(url), int(statusCode), responseTime))
            except Exception:
                print(line)
                continue


df = df.from_records(rows, columns=['Time', 'IP', 'HttpMethod', 'URL', 'StatusCode', 'ResponseTime'])
# Out:
# Opening file access.log.2
# Opening file access.log.5
# Opening file access.log.10
# Opening file access.log.1
# Opening file access.log.4
# Opening file access.log.14
# Opening file access.log.11
# ['10.100.10.200', '-', '-', '[02/Jul/2020:03:00:32', '+0500]', '"\\x15\\x03\\x03\\x00\\x02\\x01\\x00"', '400', '173', '"-"', '"-"rt=0.003', 'uct="-"', 'uht="-"', 'urt="-"']
# Opening file access.log
# Opening file access.log.7
# Opening file access.log.8
# Opening file access.log.6
# Opening file access.log.13
# Opening file access.log.12
# Opening file access.log.3
# Opening file access.log.9
# ['10.100.10.200', '-', '-', '[04/Jul/2020:03:02:08', '+0500]', '"\\x15\\x03\\x03\\x00\\x02\\x01\\x00"', '400', '173', '"-"', '"-"rt=0.002', 'uct="-"', 'uht="-"', 'urt="-"']

# %%
df200 = df.copy()

# %%
df200 = df200.loc[df200['StatusCode'] == 200]

# %%
df200['Date'] = df200.apply(lambda x: x['Time'].date(), axis=1)

# %%
df200['URT'] = df200.apply(lambda x: float(x['ResponseTime']), axis=1)

# %%
df200['Module'] = df200.apply(lambda x: x['URL'].split('/')[1], axis=1)

# %%
df200.plot(y='URT', x='Time', kind='scatter', figsize=(16, 8), title='Response Time Distribution')
plt.show()

# %%
modules = np.unique(df200.Module)
colors = [plt.cm.tab10(i/float(len(modules)-1)) for i in range(len(modules))]

# Draw Plot for Each Module
plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k');

for i, module in enumerate(modules):
    plt.scatter('Time', 'URT', 
                data=df200.loc[df200.Module==module, :], 
                s=20, color=colors[i], label=str(module));

# Decorations
plt.gca().set(xlabel='Time', ylabel='URT');

plt.xticks(fontsize=12); plt.yticks(fontsize=12);
plt.title("Response Time Distribution by Module", fontsize=22);
plt.legend(fontsize=12);   
plt.show()
